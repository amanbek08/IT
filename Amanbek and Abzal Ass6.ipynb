# %%
with open('file.txt') as f:
    my_inp = f.readlines()

print(my_inp)
n = 11
my_inp1 = [my_inp[0][i:i+n] for i in range(0, len(my_inp[0]), n)]

my_list = list(my_inp1)
# my_list = [int(x) for x in my_list]
print(my_list)

def HummingCode(my_list):
    counter = 0
    c = 0
    p1 = 0
    p2 = 0
    p3 = 0
    p4 = 0
    p5 = 0
    
    my_list = list(my_list)
    my_list = [int(x) for x in my_list]
    p1 = my_list[0] + my_list[1] + my_list[3] + my_list[4] + my_list[6] + my_list[8] + my_list[10]
    if p1 % 2 == 0:
        p1 = 0
    else:
        p1 = 1

    p2 = my_list[0] + my_list[2] + my_list[3] + my_list[5] + my_list[6] + my_list[9] + my_list[10]
    if p2 % 2 == 0:
        p2 = 0
    else:
        p2 = 1

    p3 = my_list[1] + my_list[2] + my_list[3] + my_list[7] + my_list[8] + my_list[9] + my_list[10]
    if p3 % 2 == 0:
        p3 = 0
    else:
        p3 = 1

    p4 = my_list[4] + my_list[5] + my_list[6] + my_list[7] + my_list[8] + my_list[9] + my_list[10]
    if p4 % 2 == 0:
        p4 = 0
    else:
        p4 = 1

    print(p1)
    print(p2)
    print(p3)
    print(p4)
    
    my_list.insert(0, p1)
    my_list.insert(1, p2)
    my_list.insert(3, p3)
    my_list.insert(7, p4)
    count = 0
    for i in range(0, len(my_list)):
        if my_list[i] == 1:
            count = count + 1
    if count % 2 == 0:
        p5 = 1
    my_list.insert(0, p5)
    output = ''.join([str(elem) for elem in my_list])
    print(output)
    return(output)

b1 = HummingCode(my_list[0])
b2 = HummingCode(my_list[1])
output = b1 + b2
print('Output for (15,11):')
print(output)
text_file = open("output.txt", "wt")
n = text_file.write(output)
text_file.close()
# Out:
# ['1110110001010111001110']
# ['11101100010', '10111001110']
# 1
# 0
# 1
# 1
# 0101111011100010
# 0
# 0
# 1
# 0
# 1001101101001110
# Output for (15,11):
# 01011110111000101001101101001110

# %%
with open('file.txt') as f:
    my_inp = f.readlines()
while(len(my_inp[0]) % 4 != 0):
    my_inp[0] = my_inp[0] + '0'

print(my_inp)
n = 4
my_inp2 = [my_inp[0][i:i+n] for i in range(0, len(my_inp[0]), n)]

my_list = list(my_inp2)
# my_list = [int(x) for x in my_list]
print(my_list)

def HummingCode2(my_list):
    counter = 0
    c = 0
    p1 = 0
    p2 = 0
    p3 = 0
    p4 = 0
    
    my_list = list(my_list)
    my_list = [int(x) for x in my_list]
    p1 = my_list[0] + my_list[1] + my_list[3]
    if p1 % 2 == 0:
        p1 = 0
    else:
        p1 = 1

    p2 = my_list[0] + my_list[2] + my_list[3]
    if p2 % 2 == 0:
        p2 = 0
    else:
        p2 = 1

    p3 = my_list[1] + my_list[2] + my_list[3]
    if p3 % 2 == 0:
        p3 = 0
    else:
        p3 = 1

    print(p1)
    print(p2)
    print(p3)
    
    my_list.insert(0, p1)
    my_list.insert(1, p2)
    my_list.insert(3, p3)
    count = 0
    
    for i in range(0, len(my_list)):
        if my_list[i] == 1:
            count = count + 1
    if count % 2 == 0:
        p4 = 1
    my_list.insert(0, p4)
    output = ''.join([str(elem) for elem in my_list])
    print(output)
    return(output)

b1 = HummingCode2(my_list[0])
b2 = HummingCode2(my_list[1])
b3 = HummingCode2(my_list[2])
b4 = HummingCode2(my_list[3])
b5 = HummingCode2(my_list[4])
b6 = HummingCode2(my_list[5])
output = b1 + b2 + b3 + b4 + b5 + b6
print('Output for (7,4):')
print(output)   


text_file = open("output.txt", "wt")
n = text_file.write(output)
text_file.close()
# Out:
# ['111011000101011100111000']
# ['1110', '1100', '0101', '0111', '0011', '1000']
# 0
# 0
# 0
# 00010110
# 0
# 1
# 1
# 10111100
# 0
# 1
# 0
# 00100101
# 0
# 0
# 1
# 10001111
# 1
# 0
# 0
# 01000011
# 1
# 1
# 0
# 01110000
# Output for (7,4):
# 000101101011110000100101100011110100001101110000
